# %%
import pandas as pd

data = pd.read_csv('~/Desktop/data_sf.csv')
s = data['Nationality'].value_counts()
print(s.index)
print()
print(len(s.index))
# Out:
# Index(['England', 'Germany', 'Spain', 'France', 'Argentina', 'Italy',
#        'Colombia', 'Japan', 'Brazil', 'China PR',
#        ...
#        'Andorra', 'St Lucia', 'South Sudan', 'Philippines', 'Botswana',
#        'Libya', 'Central African Rep.', 'Bermuda', 'Belize', 'Oman'],
#       dtype='object', length=156)
#
# 156

# %%
import pandas as pd

data = pd.read_csv('~/Desktop/data_sf.csv')
s_unique = data['Nationality'].unique()
print(s_unique)

s_unique_count = data['Nationality'].nunique()
print(s_unique_count)
# Out:
# ['Argentina' 'Portugal' 'Brazil' 'Spain' 'Belgium' 'Croatia' 'Uruguay'
#  'Slovenia' 'Poland' 'Germany' 'France' 'England' 'Italy' 'Egypt'
#  'Colombia' 'Denmark' 'Gabon' 'Wales' 'Senegal' 'Costa Rica' 'Slovakia'
#  'Netherlands' 'Bosnia Herzegovina' 'Morocco' 'Serbia' 'Algeria' 'Austria'
#  'Greece' 'Chile' 'Sweden' 'Korea Republic' 'Finland' 'Guinea'
#  'Montenegro' 'Switzerland' 'Norway' 'DR Congo' 'Ukraine' 'Mexico'
#  'Czech Republic' 'Ivory Coast' 'Albania' 'Turkey' 'Ghana' 'Ecuador'
#  'Mali' 'Nigeria' 'Dominican Republic' 'Japan' 'Cameroon'
#  'Republic of Ireland' 'Romania' 'United States' 'Russia' 'Hungary'
#  'Iceland' 'Zimbabwe' 'Togo' 'Angola' 'Burkina Faso' 'Peru' 'Scotland'
#  'Venezuela' 'Estonia' 'Tunisia' 'Israel' 'Equatorial Guinea'
#  'New Zealand' 'FYR Macedonia' 'Paraguay' 'China PR' 'Kosovo' 'Tanzania'
#  'Iran' 'Uzbekistan' 'South Africa' 'Australia' 'Congo' 'Jamaica'
#  'Mozambique' 'Cape Verde' 'Northern Ireland' 'Syria' 'Cyprus' 'Moldova'
#  'Canada' 'Trinidad & Tobago' 'Bulgaria' 'Georgia' 'Saudi Arabia'
#  'Armenia' 'Guinea Bissau' 'Haiti' 'Comoros' 'Eritrea' 'Oman' 'Iraq'
#  'Latvia' 'Panama' 'Bolivia' 'Madagascar' 'Belarus' 'Honduras' 'Thailand'
#  'Mauritius' 'Gambia' 'Guatemala' 'Central African Rep.' 'Zambia'
#  'Curacao' 'Niger' 'Mauritania' 'Suriname' 'Benin' 'Luxembourg' 'Kenya'
#  'Montserrat' 'Namibia' 'Azerbaijan' 'Guam' 'Libya' 'Faroe Islands'
#  'Nicaragua' 'Sierra Leone' 'Kazakhstan' 'Lithuania' 'Barbados' 'Lebanon'
#  'Liechtenstein' 'Palestine' 'Guyana' 'Korea DPR' 'El Salvador' 'Cuba'
#  'Sudan' 'Burundi' 'St Lucia' 'Ethiopia' 'Uganda' 'Puerto Rico' 'Grenada'
#  'Antigua & Barbuda' 'Jordan' 'Rwanda' 'Bermuda' 'Qatar' 'Afghanistan'
#  'Hong Kong' 'Andorra' 'Malta' 'Belize' 'South Sudan' 'St Kitts Nevis'
#  'Philippines' 'Indonesia' 'Botswana']
# 156

# %%
import pandas as pd

data = pd.read_csv('~/Desktop/data_sf.csv')
s_unique = data['Nationality'].unique()
print(len(s_unique))

s_unique_count = data['Nationality'].nunique()
print(s_unique_count)
# Out:
# 156
# 156

# %%
import pandas as pd

data = pd.read_csv('~/Desktop/data_sf.csv')
s = data['Nationality'].value_counts()
#print(s.reset_index())
s.columns=['Nationality','Players Count']
print(s.head())
# Out:
# England      1368
# Germany       919
# Spain         671
# France        614
# Argentina     574
# Name: Nationality, dtype: int64

# %%
import pandas as pd

data = pd.read_csv('~/Desktop/data_sf.csv')

display(data)

data[data.Nationality == 'Spain'].Wage.value_counts(bins = 4, normalize = True)
# Out:
#        Unnamed: 0                Name  Age Nationality                 Club  \
# 0               0            L. Messi   31   Argentina         FC Barcelona
# 1               1   Cristiano Ronaldo   33    Portugal             Juventus
# 2               2           Neymar Jr   26      Brazil  Paris Saint-Germain
# 3               3              De Gea   27       Spain    Manchester United
# 4               4        K. De Bruyne   27     Belgium      Manchester City
# ...           ...                 ...  ...         ...                  ...
# 12892       13121        J. Lundstram   19     England      Crewe Alexandra
# 12893       13122  N. Christoffersson   19      Sweden       Trelleborgs FF
# 12894       13123           B. Worman   16     England     Cambridge United
# 12895       13124      D. Walker-Rice   17     England      Tranmere Rovers
# 12896       13125           G. Nugent   16     England      Tranmere Rovers
#
#            Value    Wage Position  Crossing  Finishing  ...  Penalties  \
# 0      110500000  565000       RF        84         95  ...         75
# 1       77000000  405000       ST        84         94  ...         85
# 2      118500000  290000       LW        79         87  ...         81
# 3       72000000  260000       GK        17         13  ...         40
# 4      102000000  355000      RCM        93         82  ...         79
# ...          ...     ...      ...       ...        ...  ...        ...
# 12892    1100000    1000       CM        34         38  ...         43
# 12893      60000    1000       ST        23         52  ...         43
# 12894      60000    1000       ST        25         40  ...         55
# 12895      60000    1000       RW        44         50  ...         50
# 12896      60000    1000       CM        41         34  ...         33
#
#        Composure  Marking  StandingTackle  SlidingTackle  GKDiving  \
# 0             96       33              28             26         6
# 1             95       28              31             23         7
# 2             94       27              24             33         9
# 3             68       15              21             13        90
# 4             88       68              58             51        15
# ...          ...      ...             ...            ...       ...
# 12892         45       40              48             47        10
# 12893         42       22              15             19        10
# 12894         41       32              13             11         6
# 12895         46       20              25             27        14
# 12896         43       40              43             50        10
#
#        GKHandling  GKKicking  GKPositioning  GKReflexes
# 0              11         15             14           8
# 1              11         15             14          11
# 2               9         15             15          11
# 3              85         87             88          94
# 4              13          5             10          13
# ...           ...        ...            ...         ...
# 12892          13          7              8           9
# 12893           9          9              5          12
# 12894           5         10              6          13
# 12895           6         14              8           9
# 12896          15          9             12           9
#
# [12897 rows x 42 columns]
# (620.999, 95750.0]      0.970194
# (95750.0, 190500.0]     0.016393
# (190500.0, 285250.0]    0.008942
# (285250.0, 380000.0]    0.004471
# Name: Wage, dtype: float64

# %%
import pandas as pd

data = pd.read_csv('~/Desktop/data_sf.csv')

display(data)

data[data.Club == 'Manchester United'].Nationality.nunique()
# Out:
#        Unnamed: 0                Name  Age Nationality                 Club  \
# 0               0            L. Messi   31   Argentina         FC Barcelona
# 1               1   Cristiano Ronaldo   33    Portugal             Juventus
# 2               2           Neymar Jr   26      Brazil  Paris Saint-Germain
# 3               3              De Gea   27       Spain    Manchester United
# 4               4        K. De Bruyne   27     Belgium      Manchester City
# ...           ...                 ...  ...         ...                  ...
# 12892       13121        J. Lundstram   19     England      Crewe Alexandra
# 12893       13122  N. Christoffersson   19      Sweden       Trelleborgs FF
# 12894       13123           B. Worman   16     England     Cambridge United
# 12895       13124      D. Walker-Rice   17     England      Tranmere Rovers
# 12896       13125           G. Nugent   16     England      Tranmere Rovers
#
#            Value    Wage Position  Crossing  Finishing  ...  Penalties  \
# 0      110500000  565000       RF        84         95  ...         75
# 1       77000000  405000       ST        84         94  ...         85
# 2      118500000  290000       LW        79         87  ...         81
# 3       72000000  260000       GK        17         13  ...         40
# 4      102000000  355000      RCM        93         82  ...         79
# ...          ...     ...      ...       ...        ...  ...        ...
# 12892    1100000    1000       CM        34         38  ...         43
# 12893      60000    1000       ST        23         52  ...         43
# 12894      60000    1000       ST        25         40  ...         55
# 12895      60000    1000       RW        44         50  ...         50
# 12896      60000    1000       CM        41         34  ...         33
#
#        Composure  Marking  StandingTackle  SlidingTackle  GKDiving  \
# 0             96       33              28             26         6
# 1             95       28              31             23         7
# 2             94       27              24             33         9
# 3             68       15              21             13        90
# 4             88       68              58             51        15
# ...          ...      ...             ...            ...       ...
# 12892         45       40              48             47        10
# 12893         42       22              15             19        10
# 12894         41       32              13             11         6
# 12895         46       20              25             27        14
# 12896         43       40              43             50        10
#
#        GKHandling  GKKicking  GKPositioning  GKReflexes
# 0              11         15             14           8
# 1              11         15             14          11
# 2               9         15             15          11
# 3              85         87             88          94
# 4              13          5             10          13
# ...           ...        ...            ...         ...
# 12892          13          7              8           9
# 12893           9          9              5          12
# 12894           5         10              6          13
# 12895           6         14              8           9
# 12896          15          9             12           9
#
# [12897 rows x 42 columns]
# 13

# %%
import pandas as pd

data = pd.read_csv('~/Desktop/data_sf.csv')

display(data)

data[(data.Nationality == 'Brazil') & (data.Club == 'Juventus')].Name.unique()
# Out:
#        Unnamed: 0                Name  Age Nationality                 Club  \
# 0               0            L. Messi   31   Argentina         FC Barcelona
# 1               1   Cristiano Ronaldo   33    Portugal             Juventus
# 2               2           Neymar Jr   26      Brazil  Paris Saint-Germain
# 3               3              De Gea   27       Spain    Manchester United
# 4               4        K. De Bruyne   27     Belgium      Manchester City
# ...           ...                 ...  ...         ...                  ...
# 12892       13121        J. Lundstram   19     England      Crewe Alexandra
# 12893       13122  N. Christoffersson   19      Sweden       Trelleborgs FF
# 12894       13123           B. Worman   16     England     Cambridge United
# 12895       13124      D. Walker-Rice   17     England      Tranmere Rovers
# 12896       13125           G. Nugent   16     England      Tranmere Rovers
#
#            Value    Wage Position  Crossing  Finishing  ...  Penalties  \
# 0      110500000  565000       RF        84         95  ...         75
# 1       77000000  405000       ST        84         94  ...         85
# 2      118500000  290000       LW        79         87  ...         81
# 3       72000000  260000       GK        17         13  ...         40
# 4      102000000  355000      RCM        93         82  ...         79
# ...          ...     ...      ...       ...        ...  ...        ...
# 12892    1100000    1000       CM        34         38  ...         43
# 12893      60000    1000       ST        23         52  ...         43
# 12894      60000    1000       ST        25         40  ...         55
# 12895      60000    1000       RW        44         50  ...         50
# 12896      60000    1000       CM        41         34  ...         33
#
#        Composure  Marking  StandingTackle  SlidingTackle  GKDiving  \
# 0             96       33              28             26         6
# 1             95       28              31             23         7
# 2             94       27              24             33         9
# 3             68       15              21             13        90
# 4             88       68              58             51        15
# ...          ...      ...             ...            ...       ...
# 12892         45       40              48             47        10
# 12893         42       22              15             19        10
# 12894         41       32              13             11         6
# 12895         46       20              25             27        14
# 12896         43       40              43             50        10
#
#        GKHandling  GKKicking  GKPositioning  GKReflexes
# 0              11         15             14           8
# 1              11         15             14          11
# 2               9         15             15          11
# 3              85         87             88          94
# 4              13          5             10          13
# ...           ...        ...            ...         ...
# 12892          13          7              8           9
# 12893           9          9              5          12
# 12894           5         10              6          13
# 12895           6         14              8           9
# 12896          15          9             12           9
#
# [12897 rows x 42 columns]
# array(['Alex Sandro', 'Douglas Costa'], dtype=object)

# %%
import pandas as pd

data = pd.read_csv('~/Desktop/data_sf.csv')

#display(data)

data[(data.Age > 35)].Club.value_counts()
# Out:
# Club Atlético Huracán         4
# Hokkaido Consadole Sapporo    4
# Club Atlético Tigre           3
# Club Atlético Colón           3
# San Martín de San Juan        3
#                              ..
# Tianjin TEDA FC               1
# Urawa Red Diamonds            1
# Celtic                        1
# Pogoń Szczecin                1
# Montpellier HSC               1
# Name: Club, Length: 212, dtype: int64

# %%
import pandas as pd

data = pd.read_csv('~/Desktop/data_sf.csv')

#display(data)

data[(data.Nationality == 'Argentina')].Age.value_counts(bins = 4)
# Out:
# (22.25, 28.5]      200
# (15.974, 22.25]    197
# (28.5, 34.75]      128
# (34.75, 41.0]       49
# Name: Age, dtype: int64

# %%
import pandas as pd

data = pd.read_csv('~/Desktop/data_sf.csv')

#display(data)

data[(data.Nationality == 'Spain')].Age.value_counts(normalize = True)
# Out:
# 21    0.117735
# 22    0.095380
# 20    0.077496
# 23    0.071535
# 25    0.064083
# 27    0.062593
# 24    0.059613
# 28    0.053651
# 26    0.053651
# 19    0.047690
# 29    0.047690
# 18    0.038748
# 30    0.038748
# 31    0.032787
# 32    0.032787
# 33    0.031297
# 34    0.022355
# 17    0.013413
# 35    0.011923
# 36    0.010432
# 37    0.008942
# 16    0.002981
# 39    0.002981
# 38    0.001490
# Name: Age, dtype: float64

# %%
import pandas as pd

data = pd.read_csv('~/Desktop/data_sf.csv')

#display(data)

club_dataframe = data.groupby(['Club'])[['Wage']].agg(['mean', 'median'])
new_club_dataframe = club_dataframe.reset_index()
new_club_dataframe.columns = ['Club', 'Mean', 'Median']
#display(new_club_dataframe)

lookup_dataframe = new_club_dataframe[(new_club_dataframe.Mean == new_club_dataframe.Median)]
#display(lookup_dataframe)
print('Count:')
print(lookup_dataframe.nunique())
print('Max:')
print(lookup_dataframe.Mean.max())
print('Club:')
print(lookup_dataframe[(lookup_dataframe.Mean == lookup_dataframe.Mean.max())].Club)
# Out:
# Count:
# Club      52
# Mean       8
# Median     8
# dtype: int64
# Max:
# 13000.0
# Club:
# 168    Cruzeiro
# Name: Club, dtype: object

# %%
import pandas as pd

data = pd.read_csv('~/Desktop/data_sf.csv')

#display(data)


a = data.groupby(['Nationality'])[['Wage','Age']]
a = a.reset_index()
print(a.head(10))
a.columns = ['Nationality', 'Wage', 'Age']
a[(a.Nationality == 'Argentina') & (a.Age == 20)].Wage
# Out:
# 54000
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-88-57de74b55912> in <module>
#       9 a.Wage.max()
#      10 a = data.groupby(['Nationality'])[['Wage','Age']]
# ---> 11 a = a.reset_index()
#      12 print(a.head(10))
#      13 a.columns = ['Nationality', 'Wage', 'Age']
#
# ~/.local/lib/python3.9/site-packages/pandas/core/groupby/groupby.py in __getattr__(self, attr)
#     750             return self[attr]
#     751
# --> 752         raise AttributeError(
#     753             f"'{type(self).__name__}' object has no attribute '{attr}'"
#     754         )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'reset_index'

# %%
import pandas as pd

data = pd.read_csv('~/Desktop/data_sf.csv')

#display(data)

#a = data[(data.Nationality == 'Argentina') & (data.Age == 20)]

a = data.groupby(['Nationality'])[['Wage','Age']].max()
a = a.reset_index()

a.columns = ['Nationality', 'Wage', 'Age']
display(a)
# Out:
#      Nationality    Wage  Age
# 0    Afghanistan    2000   26
# 1        Albania   58000   34
# 2        Algeria  205000   35
# 3        Andorra    1000   28
# 4         Angola   44000   30
# ..           ...     ...  ...
# 151   Uzbekistan   17000   30
# 152    Venezuela   42000   34
# 153        Wales  355000   37
# 154       Zambia    6000   28
# 155     Zimbabwe   20000   34
#
# [156 rows x 3 columns]

# %%
import pandas as pd

data = pd.read_csv('~/Desktop/data_sf.csv')

#display(data)

a = data[(data.Nationality == 'Argentina') & (data.Club == 'FC Barcelona')]
b = a.groupby(['Club'])[['Strength', 'Balance']].max()
display(b)
# Out:
#               Strength  Balance
# Club
# FC Barcelona        59       95

# %%
import pandas as pd

data = pd.read_csv('~/Desktop/data_sf.csv')
#display(data)

#df = data.groupby(['Club', 'Position']).Position.nunique()

#display(df)
pivot = data.pivot_table(values = ['Name'],
                        index = ['Position'],
                        columns = ['Club'],
                        aggfunc = 'count',
                        margins = False,
                        fill_value = 0)
#display(pivot)
print(round(pivot.loc['GK'].mean(), 3))
new_df = pivot.loc['CM']
display(new_df)
new_df.value_counts()
# Out:
# 2.525
#       Club
# Name   SSV Jahn Regensburg     2
#       1. FC Heidenheim 1846    1
#       1. FC Kaiserslautern     0
#       1. FC Köln               2
#       1. FC Magdeburg          0
#                               ..
#       Zagłębie Sosnowiec       0
#       Çaykur Rizespor          0
#       Örebro SK                1
#       Östersunds FK            3
#       Śląsk Wrocław            1
# Name: CM, Length: 650, dtype: int64
# 1    211
# 2    149
# 0    136
# 3     89
# 4     39
# 5     21
# 6      5
# Name: CM, dtype: int64

# %%
import pandas as pd

data = pd.read_csv('~/Desktop/data_sf.csv')
#display(data)

pivot = data.loc[data['Club'].isin(['AS Monaco'])].pivot_table(values = ['Wage'],
                        index = ['Nationality'],
                        columns = ['Club'],
                        aggfunc = 'sum',
                        margins = False,
                        fill_value = 0)
display(pivot)
display(pivot.loc['Russia'])
# Out:
#                  Wage
# Club        AS Monaco
# Nationality
# Belgium         47000
# Brazil          55000
# Colombia       115000
# Croatia         70000
# France          95000
# Italy           48000
# Montenegro      79000
# Morocco         39000
# Poland          86000
# Portugal        65000
# Russia          61000
# Senegal         10000
#       Club
# Wage  AS Monaco    61000
# Name: Russia, dtype: int64

# %%
import pandas as pd

data = pd.read_csv('~/Desktop/data_sf.csv')
#display(data)

pivot = data.loc[data['Position'].isin(['RB', 'LM', 'RM', 'CF', 'RWM', 'RS', 'ST'])].pivot_table(
                        index = ['Position'],
                        columns = ['Club'],
                        values = ['SprintSpeed'],
                        aggfunc = 'mean',
                        margins = True,
                        fill_value = 0)
#display(pivot)
pivot1=pivot.loc['All']
pivot1 = pivot1.reset_index()
pivot1.columns=['A','B', 'C']
pivot1 = pivot1.sort_values(['C'], ascending=False)
display(pivot1)
#p1 = pivot.reset_index()
#display(p1.loc['all'])
#p1.sort_values(['All'], ascending=False)
#display(p1)
# Out:
#                A                    B          C
# 6    SprintSpeed   1. FC Union Berlin  86.000000
# 230  SprintSpeed             FC Porto  84.500000
# 372  SprintSpeed    Manchester United  84.333333
# 312  SprintSpeed                Inter  84.000000
# 360  SprintSpeed            Liverpool  83.833333
# ..           ...                  ...        ...
# 406  SprintSpeed    Nottingham Forest  56.500000
# 136  SprintSpeed        Chievo Verona  55.666667
# 559  SprintSpeed     Stade Rennais FC  55.000000
# 446  SprintSpeed      Portimonense SC  53.333333
# 125  SprintSpeed  Ceará Sporting Club  52.000000
#
# [649 rows x 3 columns]

# %%
import pandas as pd

df_movies = pd.read_csv('~/Documents/Python/Unit1Data/movies.csv')
df_ratings = pd.read_csv('~/Documents/Python/Unit1Data/ratings.csv')
display(df_movies)

#display(df_ratings)
print(df_ratings.rating.max())
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# 4                                          Comedy
# ...                                           ...
# 9737              Action|Animation|Comedy|Fantasy
# 9738                     Animation|Comedy|Fantasy
# 9739                                        Drama
# 9740                             Action|Animation
# 9741                                       Comedy
#
# [9742 rows x 3 columns]
# 5.0

# %%
import pandas as pd

movies = pd.read_csv('~/Documents/Python/Unit1Data/movies.csv')
ratings = pd.read_csv('~/Documents/Python/Unit1Data/ratings.csv')
joined = ratings.merge(movies, on='movieId', how='left')

joined.head()
# Out:
#    userId  movieId  rating  timestamp                        title  \
# 0       1        1     4.0  964982703             Toy Story (1995)
# 1       1        3     4.0  964981247      Grumpier Old Men (1995)
# 2       1        6     4.0  964982224                  Heat (1995)
# 3       1       47     5.0  964983815  Seven (a.k.a. Se7en) (1995)
# 4       1       50     5.0  964982931   Usual Suspects, The (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                               Comedy|Romance
# 2                        Action|Crime|Thriller
# 3                             Mystery|Thriller
# 4                       Crime|Mystery|Thriller

# %%
import pandas as pd

ratings = pd.read_csv('~/Documents/Python/Unit1Data/ratings_example.txt', sep='\t')
display(ratings)
print("---")

movies = pd.read_csv('~/Documents/Python/Unit1Data/movies_example.txt', sep='\t')
display(movies)
print("---")

movies.drop_duplicates(subset='movieId', keep = 'first', inplace = True)
display(movies)
print("---")


joined = ratings.merge(movies, on='movieId', how='left')
display(joined)
# Out:
#    userId  movieId  rating   timestamp
# 0       1       31     2.5  1260759144
# ---
#    movieId                                      title                   genres
# 0       31                    Dangerous Minds (1995)                     Drama
# 1       32  Twelve Monkeys (a.k.a. 12 Monkeys) (1995)  Mystery|Sci-Fi|Thriller
# 2       31                    Dangerous Minds (1995)                     Drama
# ---
#    movieId                                      title                   genres
# 0       31                    Dangerous Minds (1995)                     Drama
# 1       32  Twelve Monkeys (a.k.a. 12 Monkeys) (1995)  Mystery|Sci-Fi|Thriller
# ---
#    userId  movieId  rating   timestamp                    title genres
# 0       1       31     2.5  1260759144  Dangerous Minds (1995)   Drama

# %%
import pandas as pd
items_dict = {

    'item_id': [417283, 849734, 132223, 573943, 19475, 3294095, 382043, 302948, 100132, 312394], 

    'vendor': ['Samsung', 'LG', 'Apple', 'Apple', 'LG', 'Apple', 'Samsung', 'Samsung', 'LG', 'ZTE'],

    'stock_count': [54, 33, 122, 18, 102, 43, 77, 143, 60, 19]

}

purchase_log = {

    'purchase_id': [101, 101, 101, 112, 121, 145, 145, 145, 145, 221],

    'item_id': [417283, 849734, 132223, 573943, 19475, 3294095, 382043, 302948, 103845, 100132], 

    'price': [13900, 5330, 38200, 49990, 9890, 33000, 67500, 34500, 89900, 11400]

}

items_df = pd.DataFrame(items_dict)
purchase_df = pd.DataFrame(purchase_log)

joined = purchase_df.merge(items_df, on='item_id', how='inner')
joined['Amount']=joined['stock_count']*joined['price']
joined = joined.sort_values(['Amount'], ascending = False)
print(joined['Amount'].sum())
display(joined)
# Out:
# 19729490
#    purchase_id  item_id  price   vendor  stock_count   Amount
# 6          145   382043  67500  Samsung           77  5197500
# 7          145   302948  34500  Samsung          143  4933500
# 2          101   132223  38200    Apple          122  4660400
# 5          145  3294095  33000    Apple           43  1419000
# 4          121    19475   9890       LG          102  1008780
# 3          112   573943  49990    Apple           18   899820
# 0          101   417283  13900  Samsung           54   750600
# 8          221   100132  11400       LG           60   684000
# 1          101   849734   5330       LG           33   175890

# %%
import pandas as pd
import os

files = os.listdir('/home/lynetsea/Documents/Python/Unit1Data/data')
files
# Out:
# ['ratings_4.txt',
#  'ratings_8.txt',
#  'ratings_6.txt',
#  'ratings_9.txt',
#  'ratings_7.txt',
#  'ratings_10.txt',
#  'ratings_5.txt',
#  'ratings_3.txt',
#  'ratings_1.txt',
#  'ratings_2.txt']

# %%
files = ['setup.py', 'ratings.txt', 'stock_stats.txt', 'movies.txt', 'run.sh', 'game_of_thrones.mov']
data = [file for file in files if file.endswith('.txt')]
print(data
# Out:
# ['ratings.txt', 'stock_stats.txt', 'movies.txt']

# %%
import pandas as pd
import os

for root, dirs, files in os.walk('/home/lynetsea/Documents/Python/Unit1Data/data'):
    print(root, dirs, files)
    print("---")
# Out:
# /home/lynetsea/Documents/Python/Unit1Data/data ['subfolder'] ['ratings_4.txt', 'ratings_8.txt', 'ratings_6.txt', 'ratings_9.txt', 'ratings_7.txt', 'ratings_10.txt', 'ratings_5.txt', 'ratings_3.txt', 'ratings_1.txt', 'ratings_2.txt']
# ---
# /home/lynetsea/Documents/Python/Unit1Data/data/subfolder [] ['ratings_4.txt', 'ratings_8.txt', 'ratings_6.txt', 'ratings_9.txt', 'ratings_7.txt', 'ratings_10.txt', 'ratings_5.txt', 'ratings_3.txt', 'ratings_1.txt', 'ratings_2.txt']
# ---

# %%
import pandas as pd
import os

os_path='/home/lynetsea/Documents/Python/Unit1Data/data'
data = pd.DataFrame(columns = ['userId', 'movieId', 'rating', 'timestamp'])
files = os.listdir(os_path)

for filename in files:
    temp = pd.read_csv(os.path.join(os_path, filename), names = ['userId', 'movieId', 'rating', 'timestamp'] )
    data = pd.concat([data, temp])
    
display(data)
# Out:
#      userId movieId  rating   timestamp
# 0       213   73017     4.0  1462634113
# 1       213   73042     1.5  1462637236
# 2       213   73268     3.5  1462639582
# 3       213   73319     3.0  1462637026
# 4       213   74154     3.0  1462637115
# ...     ...     ...     ...         ...
# 9995    133   65188     4.0  1416166822
# 9996    133   68157     5.0  1416147245
# 9997    133   69757     4.5  1416151741
# 9998    133   69844     4.0  1416151678
# 9999    133   71899     3.0  1416147749
#
# [100004 rows x 4 columns]

# %%
import pandas as pd

movies = pd.read_csv('~/Documents/Python/Unit1Data/movies.csv')
ratings = pd.read_csv('~/Documents/Python/Unit1Data/ratings.csv')
joined = ratings.merge(movies, on='movieId', how='outer')

display(joined)
# Out:
#         userId  movieId  rating     timestamp  \
# 0          1.0        1     4.0  9.649827e+08
# 1          5.0        1     4.0  8.474350e+08
# 2          7.0        1     4.5  1.106636e+09
# 3         15.0        1     2.5  1.510578e+09
# 4         17.0        1     4.5  1.305696e+09
# ...        ...      ...     ...           ...
# 100849     NaN    30892     NaN           NaN
# 100850     NaN    32160     NaN           NaN
# 100851     NaN    32371     NaN           NaN
# 100852     NaN    34482     NaN           NaN
# 100853     NaN    85565     NaN           NaN
#
#                                      title  \
# 0                         Toy Story (1995)
# 1                         Toy Story (1995)
# 2                         Toy Story (1995)
# 3                         Toy Story (1995)
# 4                         Toy Story (1995)
# ...                                    ...
# 100849  In the Realms of the Unreal (2004)
# 100850            Twentieth Century (1934)
# 100851           Call Northside 777 (1948)
# 100852        Browning Version, The (1951)
# 100853                  Chalet Girl (2011)
#
#                                              genres
# 0       Adventure|Animation|Children|Comedy|Fantasy
# 1       Adventure|Animation|Children|Comedy|Fantasy
# 2       Adventure|Animation|Children|Comedy|Fantasy
# 3       Adventure|Animation|Children|Comedy|Fantasy
# 4       Adventure|Animation|Children|Comedy|Fantasy
# ...                                             ...
# 100849                        Animation|Documentary
# 100850                                       Comedy
# 100851                        Crime|Drama|Film-Noir
# 100852                                        Drama
# 100853                               Comedy|Romance
#
# [100854 rows x 6 columns]

# %%
import pandas as pd

movies = pd.read_csv('~/Documents/Python/Unit1Data/movies.csv')
ratings = pd.read_csv('~/Documents/Python/Unit1Data/ratings.csv')
joined = ratings.merge(movies, on='movieId', how='outer')

display(joined[joined['movieId'] == 3456])
# Out:
#         userId  movieId  rating  timestamp  \
# 100839     NaN     3456     NaN        NaN
#
#                                                title genres
# 100839  Color of Paradise, The (Rang-e khoda) (1999)  Drama
