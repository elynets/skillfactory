# %%
# Importing tools for EDA.  

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from itertools import combinations
from scipy.stats import ttest_ind

# Importing input data
df = pd.read_csv('~/Documents/Git/skillfactory/Unit2/datasheet/prj2_eda_stud_math.csv')

display(data.head(3))
df.info()

# First conclusion: We are going to predict the influence of different factors (columns)
# on score (column).  
# That is why I`ll drop all NaN values at score colum first.  
df.dropna(subset = ["score"], inplace=True)

# Let`s see the columns names.  
df.columns

# Let`s rename some columns to a common pattern.  
df.columns = ['school', 'sex', 'age', 'addr', 'famsize', 'pstatus', 'medu', 'fedu',
       'mjob', 'fjob', 'reason', 'guardian', 'traveltime', 'studytime',
       'failures', 'schoolsup', 'famsup', 'paidlessons', 'activities', 'nursery',
       'granular', 'wishhigher', 'internet', 'romantic', 'famrel',
       'freetime', 'goout', 'health', 'absences', 'score']

#Let`s see the results of renaming.  
display(df.head(40))
# Out:
#   school sex  age addr famsize pstatus  medu  fedu     mjob     fjob  reason  \
# 0     GP   F   18    U     NaN       A   4.0   4.0  at_home  teacher  course
# 1     GP   F   17    U     GT3     NaN   1.0   1.0  at_home    other  course
# 2     GP   F   15    U     LE3       T   1.0   1.0  at_home    other   other
#
#   guardian  traveltime  studytime  failures schoolsup famsup paidlessons  \
# 0   mother         2.0        2.0       0.0       yes     no          no
# 1   father         1.0        2.0       0.0        no    yes          no
# 2   mother         1.0        2.0       3.0       yes     no         NaN
#
#   activities nursery wishhigher internet romantic  famrel  freetime  goout  \
# 0         no     yes        yes      NaN       no     4.0       3.0    4.0
# 1         no      no        yes      yes       no     5.0       3.0    3.0
# 2         no     yes        yes      yes      NaN     4.0       3.0    2.0
#
#    health  absences  score   col
# ...

# %%
# Let`s see how does a score data looks like.  
df.score.describe()
# Out:
# count    389.000000
# mean      52.262211
# std       22.919022
# min        0.000000
# 25%       40.000000
# 50%       55.000000
# 75%       70.000000
# max      100.000000
# Name: score, dtype: float64

# %%
df.score.hist()
# Out:
# <AxesSubplot:>

# %%
# Let`s see what data is in granular column - I have 
# no description for it`s data.  

plt.plot(df.granular, df.studytime)

# %%
# The granular and studytime are totally identical.  
# I will drop granular column from the dataset.  
df.drop(['granular'], inplace=True, axis=1)

# %%
# Let`s prepare all other data for processing.  
# Looking for missing, None and NaN data in columns.  
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 389 entries, 0 to 394
# Data columns (total 29 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   school       389 non-null    object
#  1   sex          389 non-null    object
#  2   age          389 non-null    int64
#  3   addr         374 non-null    object
#  4   famsize      362 non-null    object
#  5   pstatus      344 non-null    object
#  6   medu         386 non-null    float64
#  7   fedu         365 non-null    float64
#  8   mjob         370 non-null    object
#  9   fjob         353 non-null    object
#  10  reason       372 non-null    object
#  11  guardian     358 non-null    object
#  12  traveltime   361 non-null    float64
#  13  studytime    382 non-null    float64
#  14  failures     367 non-null    float64
#  15  schoolsup    380 non-null    object
#  16  famsup       351 non-null    object
#  17  paidlessons  350 non-null    object
# ...

# %%
def get_iqr_data(col, set_range_min=0, set_range_max=1000, set_bins=16):
    # Calculating quantiles and IQR.  
    perc25 = df[col].quantile(0.25)
    perc75 = df[col].quantile(0.75)
    iqr = perc75-perc25
    
    # Preparing output.  
    print('25th percentile:{},'.format(perc25),
         '75th pecentile:{}'.format(perc75),
         'IQR:{}'.format(iqr),
         "Outlier margins: [{a},{b}]".format(a=perc25-1.5*iqr,
                                             b=perc75+1.5*iqr))
    
    # Preparing graphics.  
    df[col].loc[df[col].between(perc25-1.5*iqr,perc75+1.5*iqr)].hist(bins=set_bins, 
                                                          range=(set_range_min,set_range_max),
                                                          label='IQR')
    df[col].hist(alpha=0.3, bins=set_bins, range=(set_range_min,set_range_max), label='All Data')
    
    plt.legend()


def get_boxplot(col):
    fig, ax = plt.subplots(figsize=(14, 4))
    sns.boxplot(x=col, y='score', data=df, ax=ax)
    plt.xticks(rotation=45)
    ax.set_title('Boxplot for '+col)
    plt.show()
def column_info(col):
    print("\n---",col,"(",df[col].dtype,")---")
    print("--Before checks:")
    display(df[col].describe())

@column_info
def check_column(col):
    df.dropna(subset=[col], inplace=True)
    if isinstance(df[col].dtype, ['object']):
        # Cleaning nan values.  
        df[col] = df[col].astype(str).apply(lambda x:None if x=='nan' else x)
        # Cleaning NaN values.  
        df[col] = df[col].astype(str).apply(lambda x:None if x.strip()=='' else x)
        # Only valid data left.  
        df[col] = df[col].loc[df[col]!='None']
        
        # Building hist
        print(df[col].hist())
        # Building boxplot
        print(get_boxplot(col))
    elif isinstance(df[col].dtype, ['int64','float64']):
        print(get_iqr_data(col, df[col].min(), df[col].max()))
        # Cleanun null 
        # df[col] = df[col].astype(str).apply(lambda x:None if pd.isnull(x) else x)
    else:
        print("UNKNOWN DATATYPE FOR COL",col)
    
    print("Null values:",df[col].isnull().values.sum())
    print("Unique values:",df[col].nunique())
    print("Total values in column: ",df[col].value_counts().sum())
    print("Valid values:")
    print(df[col].value_counts())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-351-9bb65cadec9f> in <module>
#      33
#      34 @column_info
# ---> 35 def check_column(col):
#      36     df.dropna(subset=[col], inplace=True)
#      37     if isinstance(df[col].dtype, ['object']):
#
# <ipython-input-351-9bb65cadec9f> in column_info(col)
#      28     plt.show()
#      29 def column_info(col):
# ---> 30     print("\n---",col,"(",df[col].dtype,")---")
#      31     print("--Before checks:")
#      32     display(df[col].describe())
#
# ~/Development/anaconda/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2987     def __getitem__(self, key):
#    2988         key = lib.item_from_zerodim(key)
# -> 2989         key = com.apply_if_callable(key, self)
#    2990
#    2991         if is_hashable(key):
#
# ...

# %%
cols = ['school', 'age', 'sex']
col = 'school'
for col in cols:
    check_column(col)
# Out:
# --- school ( object )---
# Null values in column: 0
# Values in:
# GP    344
# MS     45
# Name: school, dtype: int64
# Unique values in: 2
# Total values in column:  389
# AxesSubplot(0.125,0.125;0.775x0.755)
# None
#
# --- age ( int64 )---
# Null values in column: 0
# Values in:
# 16    103
# 17     98
# 15     82
# 18     80
# 19     21
# 20      3
# 21      1
# 22      1
# Name: age, dtype: int64
# Unique values in: 8
# Total values in column:  389
# AxesSubplot(0.125,0.125;0.775x0.755)
# None
#
# --- sex ( object )---
# Null values in column: 0
# Values in:
# F    204
# M    185
# Name: sex, dtype: int64
# Unique values in: 2
# Total values in column:  389
# AxesSubplot(0.125,0.125;0.775x0.755)
# None

# %%
display(data.sex.describe())
data.sex.hist()
get_boxplot('sex')
# Out:
# count     389
# unique      2
# top         F
# freq      204
# Name: sex, dtype: object

# %%
display(data.age.describe())
get_iqr_data('age', 15, 22)
# Out:
# count    389.000000
# mean      16.673522
# std        1.265662
# min       15.000000
# 25%       16.000000
# 50%       17.000000
# 75%       18.000000
# max       22.000000
# Name: age, dtype: float64
# 25th percentile:16.0, 75th pecentile:18.0 IQR:2.0 Outlier margins: [13.0,21.0]

# %%
col = 'addr'
print("Before check:")
display(pd.DataFrame(data[col].value_counts()))
display(data.head(3))

display(data[col].describe())
check_column(col)
print("After check:")
display(data[col].describe())
#get_boxplot(data.addr)
# Out:
# Before check:
#    addr
# U   291
# R    83
#   school sex  age addr famsize pstatus  medu  fedu     mjob     fjob  reason  \
# 0     GP   F   18    U     NaN       A   4.0   4.0  at_home  teacher  course
# 1     GP   F   17    U     GT3     NaN   1.0   1.0  at_home    other  course
# 2     GP   F   15    U     LE3       T   1.0   1.0  at_home    other   other
#
#   guardian  traveltime  studytime  failures schoolsup famsup paidlessons  \
# 0   mother         2.0        2.0       0.0       yes     no          no
# 1   father         1.0        2.0       0.0        no    yes          no
# 2   mother         1.0        2.0       3.0       yes     no         NaN
#
#   activities nursery wishhigher internet romantic  famrel  freetime  goout  \
# 0         no     yes        yes      NaN       no     4.0       3.0    4.0
# 1         no      no        yes      yes       no     5.0       3.0    3.0
# 2         no     yes        yes      yes      NaN     4.0       3.0    2.0
#
# ...

# %%
col = 'famsize'
print("Before check:")
display(data.head(3))
display(data[col].describe())
check_column(col)
print("After check:")
display(data[col].describe())
get_boxplot(col)
# Out:
# Before check:
#   school sex  age addr famsize pstatus  medu  fedu     mjob     fjob  reason  \
# 0     GP   F   18    U     NaN       A   4.0   4.0  at_home  teacher  course
# 1     GP   F   17    U     GT3     NaN   1.0   1.0  at_home    other  course
# 2     GP   F   15    U     LE3       T   1.0   1.0  at_home    other   other
#
#   guardian  traveltime  studytime  failures schoolsup famsup paidlessons  \
# 0   mother         2.0        2.0       0.0       yes     no          no
# 1   father         1.0        2.0       0.0        no    yes          no
# 2   mother         1.0        2.0       3.0       yes     no         NaN
#
#   activities nursery wishhigher internet romantic  famrel  freetime  goout  \
# 0         no     yes        yes      NaN       no     4.0       3.0    4.0
# 1         no      no        yes      yes       no     5.0       3.0    3.0
# 2         no     yes        yes      yes      NaN     4.0       3.0    2.0
#
#    health  absences  score   col
# ...

# %%
col = 'pstatus'
print("Before check:")
display(data.head(3))
display(data[col].describe())
check_column(col)
print("After check:")
display(data[col].describe())
get_boxplot(col)
# Out:
# Before check:
#   school sex  age addr famsize pstatus  medu  fedu     mjob   fjob  reason  \
# 1     GP   F   17    U     GT3     NaN   1.0   1.0  at_home  other  course
# 2     GP   F   15    U     LE3       T   1.0   1.0  at_home  other   other
# 3     GP   F   15    U     GT3       T   4.0   2.0   health    NaN    home
#
#   guardian  traveltime  studytime  failures schoolsup famsup paidlessons  \
# 1   father         1.0        2.0       0.0        no    yes          no
# 2   mother         1.0        2.0       3.0       yes     no         NaN
# 3   mother         1.0        3.0       0.0        no    yes         yes
#
#   activities nursery wishhigher internet romantic  famrel  freetime  goout  \
# 1         no      no        yes      yes       no     5.0       3.0    3.0
# 2         no     yes        yes      yes      NaN     4.0       3.0    2.0
# 3        yes     yes        yes      yes      yes     3.0       2.0    2.0
#
#    health  absences  score   col
# ...

# %%
data.medu.describe()
get_iqr_data('medu', 0, 4)
# Out:
# 25th percentile:2.0, 75th pecentile:4.0 IQR:2.0 Outlier margins: [-1.0,7.0]

# %%
data.fedu.describe()

data.fedu.loc[data.fedu>4].value_counts()
# Got one wrong data input. We can`t have fedu value > 4.  

get_iqr_data('fedu', 0, 4)
# Out:
# 25th percentile:2.0, 75th pecentile:3.0 IQR:1.0 Outlier margins: [0.5,4.5]

# %%
col = 'mjob'
print("Before check:")
display(data.head(3))
display(data[col].describe())
check_column(col)
print("After check:")
display(data[col].describe())
get_boxplot(col)
# Out:
# Before check:
#   school sex  age addr famsize pstatus  medu  fedu     mjob   fjob reason  \
# 2     GP   F   15    U     LE3       T   1.0   1.0  at_home  other  other
# 3     GP   F   15    U     GT3       T   4.0   2.0   health    NaN   home
# 4     GP   F   16    U     GT3       T   3.0   3.0    other  other   home
#
#   guardian  traveltime  studytime  failures schoolsup famsup paidlessons  \
# 2   mother         1.0        2.0       3.0       yes     no         NaN
# 3   mother         1.0        3.0       0.0        no    yes         yes
# 4   father         1.0        2.0       0.0        no    yes         yes
#
#   activities nursery wishhigher internet romantic  famrel  freetime  goout  \
# 2         no     yes        yes      yes      NaN     4.0       3.0    2.0
# 3        yes     yes        yes      yes      yes     3.0       2.0    2.0
# 4         no     yes        yes       no       no     4.0       3.0    2.0
#
#    health  absences  score   col
# ...

# %%
col = 'fjob'
print("Before check:")
display(data.head(3))
display(data[col].describe())
check_column(col)
print("After check:")
display(data[col].describe())
get_boxplot(col)
# Out:
# Before check:
#   school sex  age addr famsize pstatus  medu  fedu     mjob   fjob reason  \
# 2     GP   F   15    U     LE3       T   1.0   1.0  at_home  other  other
# 3     GP   F   15    U     GT3       T   4.0   2.0   health    NaN   home
# 4     GP   F   16    U     GT3       T   3.0   3.0    other  other   home
#
#   guardian  traveltime  studytime  failures schoolsup famsup paidlessons  \
# 2   mother         1.0        2.0       3.0       yes     no         NaN
# 3   mother         1.0        3.0       0.0        no    yes         yes
# 4   father         1.0        2.0       0.0        no    yes         yes
#
#   activities nursery wishhigher internet romantic  famrel  freetime  goout  \
# 2         no     yes        yes      yes      NaN     4.0       3.0    2.0
# 3        yes     yes        yes      yes      yes     3.0       2.0    2.0
# 4         no     yes        yes       no       no     4.0       3.0    2.0
#
#    health  absences  score   col
# ...

# %%
data.reason.describe()
data.reason.hist()
# Out:
# <AxesSubplot:>

# %%
data.guardian.describe()
data.guardian.hist()
# Out:
# <AxesSubplot:>

# %%
data.traveltime.describe()
get_iqr_data('traveltime',1,4)
# Out:
# 25th percentile:1.0, 75th pecentile:2.0 IQR:1.0 Outlier margins: [-0.5,3.5]

# %%
data.studytime.describe()
get_iqr_data('studytime',1,4)
# Out:
# 25th percentile:1.0, 75th pecentile:2.0 IQR:1.0 Outlier margins: [-0.5,3.5]

# %%
data.failures.describe()
get_iqr_data('failures',0,3)
# We may drop it. All not 0 results are outliers. 
# However I`ll wait
# Out:
# 25th percentile:0.0, 75th pecentile:0.0 IQR:0.0 Outlier margins: [0.0,0.0]

# %%
data.schoolsup.describe()
data.schoolsup.hist()

# Only 50 results are yes
# Out:
# count     380
# unique      2
# top        no
# freq      331
# Name: schoolsup, dtype: object

# %%
data.famsup.describe()
data.famsup.hist()
# Out:
# <AxesSubplot:>

# %%
data.paidlessons.describe()
data.paidlessons.hist()
# Out:
# <AxesSubplot:>

# %%
data.activities.describe()
data.activities.hist()
# Out:
# <AxesSubplot:>

# %%
data.nursery.describe()
data.nursery.hist()
# Out:
# <AxesSubplot:>

# %%
data.wishhigher.describe()
data.wishhigher.hist()
# Out:
# <AxesSubplot:>

# %%
data.internet.describe()
data.internet.hist()
# Out:
# <AxesSubplot:>

# %%
data.romantic.describe()
data.romantic.hist()
# Out:
# <AxesSubplot:>

# %%
data.famrel.describe()
data.famrel.loc[data.famrel<1].value_counts()
# Got one wrong data input. We can`t have fedu value < 1.  
get_iqr_data('famrel',0,5)
# Out:
# 25th percentile:4.0, 75th pecentile:5.0 IQR:1.0 Outlier margins: [2.5,6.5]

# %%
data.goout.describe()
get_iqr_data('goout',1,5)
# Out:
# 25th percentile:2.0, 75th pecentile:4.0 IQR:2.0 Outlier margins: [-1.0,7.0]

# %%
data.health.describe()
get_iqr_data('health',1,5)
# Out:
# 25th percentile:3.0, 75th pecentile:5.0 IQR:2.0 Outlier margins: [0.0,8.0]

# %%
data.absences.describe()
get_iqr_data('absences',0,50)
# Got some outliers here.
# Out:
# 25th percentile:0.0, 75th pecentile:8.0 IQR:8.0 Outlier margins: [-12.0,20.0]

# %%
# Checking all text coulumns for corrupted data.  
# Here I`m looking for 395 not empty values in column.  

def text_column_checker(col):
    #data.dropna(subset = [col], inplace=True)
    #if data[col].dtype =='object':
        # Cleaning nan values.  
     #   data[col] = data[col].astype(str).apply(lambda x:None if x=='nan' else x)
        # Cleaning NaN values.  
      #  data[col] = data[col].astype(str).apply(lambda x:None if x.strip()=='' else x)   
    print("\n---",col,"(",data[col].dtype,")---")
    print("Null values in column:",data[col].isnull().values.sum())
    print("Values in:")
    print(data[col].value_counts())
    print("Unique values in:",data[col].nunique())
    print("Total values in column: ",data[col].value_counts().sum())
    print(data[col].hist())

# Drop score NaN rows from.  
#nan_value = float("NaN")
# Converting NaN values to empty string.  
#data.replace("", nan_value, inplace=True)  

for col in data.columns:
    text_column_checker(col)
    
display(data.head(10))
# Out:
# --- school ( object )---
# Null values in column: 0
# Values in:
# GP    349
# MS     46
# Name: school, dtype: int64
# Unique values in: 2
# Total values in column:  395
# AxesSubplot(0.125,0.125;0.775x0.755)
#
# --- sex ( object )---
# Null values in column: 0
# Values in:
# F    208
# M    187
# Name: sex, dtype: int64
# Unique values in: 2
# Total values in column:  395
# AxesSubplot(0.125,0.125;0.775x0.755)
#
# --- age ( int64 )---
# Null values in column: 0
# Values in:
# 16    104
# 17     98
# 15     82
# 18     82
# 19     24
# 20      3
# 21      1
# 22      1
# Name: age, dtype: int64
# Unique values in: 8
# Total values in column:  395
# AxesSubplot(0.125,0.125;0.775x0.755)
#
# --- address ( object )---
# Null values in column: 17
# Values in:
# U    295
# R     83
# Name: address, dtype: int64
# Unique values in: 2
# Total values in column:  378
# AxesSubplot(0.125,0.125;0.775x0.755)
#
# --- famsize ( object )---
# Null values in column: 27
# Values in:
# GT3    261
# ...
