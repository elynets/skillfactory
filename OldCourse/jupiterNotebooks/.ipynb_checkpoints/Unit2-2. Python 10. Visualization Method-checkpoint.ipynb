# %%
import  pandas as pd 
df = pd.read_csv('~/Git/skillfactory/Unit2/datasheet/tips.xls')
df.head()
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
# %matplotlib inline

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
df['total_bill'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['total_bill'].plot(kind = 'hist', grid = True, title = 'Total Bill')
# Out:
# <AxesSubplot:title={'center':'Total Bill'}, ylabel='Frequency'>

# %%
df['day'].value_counts().plot(kind = 'bar', grid = True, colormap = 'coolwarm', title = 'Customers by Days')
# Out:
# <AxesSubplot:title={'center':'Customers by Days'}>

# %%
df.groupby(by = ['sex', 'smoker'])['tip'].mean().plot(kind = 'bar', grid= True)
# Out:
# <AxesSubplot:xlabel='sex,smoker'>

# %%
df[['total_bill', 'tip']].plot(kind = 'hist', grid = True, subplots = True, title = ['Total Bill', 'Tip'], legend = True)
# Out:
# array([<AxesSubplot:title={'center':'Total Bill'}, ylabel='Frequency'>,
#        <AxesSubplot:title={'center':'Tip'}, ylabel='Frequency'>],
#       dtype=object)

# %%
df[['total_bill', 'tip']].plot(x = 'total_bill', y = 'tip', kind = 'scatter', grid = True, title = 'Tip Vs Total Bill', legend = True)
# Out:
# <AxesSubplot:title={'center':'Tip Vs Total Bill'}, xlabel='total_bill', ylabel='tip'>

# %%
df.pivot_table(values = ['total_bill', 'tip'], index = 'day', aggfunc = 'mean').plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='day'>

# %%
df.pivot_table(values = 'tip', index = ['sex', 'smoker'], aggfunc = 'count').plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='sex,smoker'>

# %%
df.groupby('smoker')['tip'].count().plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='smoker'>

# %%
df['smoker'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
df['smoker'].value_counts().plot(kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv('~/Git/skillfactory/Unit2/datasheet/tips.xls')

# %%
fig = plt.figure()
axes = fig.add_axes([0,0,1,1])
axes.set_title("Gist Title")
axes.hist(df['total_bill'])
# Out:
# (array([ 7., 42., 68., 51., 31., 19., 12.,  7.,  3.,  4.]),
#  array([ 3.07 ,  7.844, 12.618, 17.392, 22.166, 26.94 , 31.714, 36.488,
#         41.262, 46.036, 50.81 ]),
#  <BarContainer object of 10 artists>)

# %%
fig = plt.figure()
axes = fig.add_axes([0,0,1,1])
axes.set_title("Gist Title")
axes.scatter(x = df['total_bill'], y = df['tip'], marker = 'x')
axes.set_title('Total Bill Vs Tip')
axes.set_xlabel('Total Bill')
axes.set_ylabel('Tip')
# Out:
# Text(0, 0.5, 'Tip')

# %%
fig = plt.figure()
#Total Bill - mainn
#Total Bill (min\max) by Days
main_axes = fig.add_axes([0,0,1,1])
main_axes.set_title("Total Bill")
main_axes.hist(df['total_bill'])
sup_axes = fig.add_axes([0.6, 0.6, 0.35, 0.35])
sup_axes.set_title("Total Bill by Days")
sup_axes.hist(df.groupby('day')['total_bill'].min())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-77-b7e6fd6c9c52> in <module>
#       7 sup_axes = fig.add_axes([0.6, 0.6, 0.35, 0.35])
#       8 sup_axes.set_title("Total Bill by Days")
# ----> 9 sup_axes.hist(df.groupby('day')['total_bill'].min(),df.groupby('day')['total_bill'].max())
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1445     def inner(ax, *args, data=None, **kwargs):
#    1446         if data is None:
# -> 1447             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1448
#    1449         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_axes.py in hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6649             # this will automatically overwrite bins,
#    6650             # so that each histogram uses the same bins
# -> 6651             m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    6652             tops.append(m)
#    6653         tops = np.array(tops, float)  # causes problems later if it's an int
#
# <__array_function__ internals> in histogram(*args, **kwargs)
#
# ~/anaconda3/lib/python3.8/site-packages/numpy/lib/histograms.py in histogram(a, bins, range, normed, weights, density)
#     790     a, weights = _ravel_and_check_weights(a, weights)
#     791
# --> 792     bin_edges, uniform_bins = _get_bin_edges(a, bins, range, weights)
#     793
#     794     # Histogram is an integer or a float array depending on the weights.
#
# ~/anaconda3/lib/python3.8/site-packages/numpy/lib/histograms.py in _get_bin_edges(a, bins, range, weights)
#     429         bin_edges = np.asarray(bins)
#     430         if np.any(bin_edges[:-1] > bin_edges[1:]):
# --> 431             raise ValueError(
#     432                 '`bins` must increase monotonically, when an array')
#     433
#
# ValueError: `bins` must increase monotonically, when an array
